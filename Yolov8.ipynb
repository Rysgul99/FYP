# %% [markdown]
# <a href="https://colab.research.google.com/github/Rysgul99/FYP/blob/main/Yolov8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# %%
# !yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source='/content/drive/MyDrive/Datasets/Data.Yolov8/GettyImages-183243429-19b6426.jpg'
# Out:
# Ultralytics YOLOv8.0.81 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8l summary (fused): 268 layers, 43668288 parameters, 0 gradients, 165.2 GFLOPs
#
# image 1/1 /content/drive/MyDrive/Datasets/Data.Yolov8/GettyImages-183243429-19b6426.jpg: 480x640 3 bottles, 63.3ms
# Speed: 0.7ms preprocess, 63.3ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3

# %% [markdown]
# # **Custom Data Training**

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=../content/drive/MyDrive/Datasets/Data.Yolov8/data.yaml epochs=50 imgsz=640
# Out:
# Ultralytics YOLOv8.0.81 🚀 Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...
